# %%
import pandas as pd

df = pd.read_csv('../csv/Final.csv')
df
# Out:
#                                                 Texto       Fecha  \
# 0   💵 Tras el retroceso de la inflación: UF caerá ...  07-07-2023
# 1                                 No será mucho lusho  08-07-2023
# 2        Es momento de tomar café y regalar flores! 🤭  07-07-2023
# 3   Mal momento para cobrar en UF 🥺 algún día toca...  08-07-2023
# 4   Disfruta de los descuentos especiales para cli...  07-07-2023
# 5   No pero espera que el gobierno comunista iba a...  07-07-2023
# 6   Tranquilos, el próximo mes sube al doble 🤣…\nA...  07-07-2023
# 7                             Viene bajando hace rato  08-07-2023
# 8                                                Kah!  08-07-2023
# 9                       Y el merluzo callampin bombin  07-07-2023
# 10  Jajajaajaj y este milagro, mañana mismo sube 3...  07-07-2023
# 11            Bien Ctm 70 pesos menos de arriendo 🫶😎😍  08-07-2023
# 12  todos celebrando la baja inflación, ¿y cuánto ...  08-07-2023
# 13                                            Kokokok  07-07-2023
# 14                        Viva  boric  gijo  de  dios  07-07-2023
# 15  Tiembla Luksic, con este ahorrito me forro y t...  07-07-2023
# 16                               Grande Pdte Boric ❤️  07-07-2023
# 17                                            Mesirve  07-07-2023
# 18                               Cago mi ahorro en UF  07-07-2023
# 19                                     No será mucho?  07-07-2023
# 20                              Culpa del borisssssss  07-07-2023
# 21  Avísenle al banco estado, haber si me baja el ...  07-07-2023
#
#             Nombre Usuario                                             Fuente  \
# 0                 cnnchile  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 1            tatiana.cid.3  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 2            flordecafe.cl  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 3              fran.quero_  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 4      cerveza_ancestrales  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 5          connietiabeanie  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 6               karonciwis  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 7                davidvr91  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 8               laidcanard  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 9          handsome_d3vil_  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 10                eduarson  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 11           soylaloreleal  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 12           franciscolodi  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 13              clau.camrg  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 14           angelicaadaia  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 15  rodrigin_pirin_pin_pin  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 16            pauli_diaz_a  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 17      granhermanochiille  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 18               sagiton78  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 19                 lugar61  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 20        caro_cancino1989  https://www.threads.net/@cnnchile/post/CuaJQgq...
# 21                 c_vejar  https://www.threads.net/@cnnchile/post/CuaJQgq...
#
#    Concepto asociado Género Grupo Étareo Escolaridad
# 0           sorpresa    N/E          N/E         N/E
# 1           sorpresa    N/E          N/E         N/E
# 2            alegría    N/E          N/E         N/E
# 3           tristeza    N/E          N/E         N/E
# 4            alegría    N/E          N/E         N/E
# 5              enojo    N/E          N/E         N/E
# 6           tristeza    N/E          N/E         N/E
# 7           sorpresa    N/E          N/E         N/E
# 8            alegría    N/E          N/E         N/E
# 9           sorpresa    N/E          N/E         N/E
# 10          sorpresa    N/E          N/E         N/E
# 11           alegría    N/E          N/E         N/E
# 12          tristeza    N/E          N/E         N/E
# 13           alegría    N/E          N/E         N/E
# 14           alegría    N/E          N/E         N/E
# 15           alegría    N/E          N/E         N/E
# 16           alegría    N/E          N/E         N/E
# 17           alegría    N/E          N/E         N/E
# 18          tristeza    N/E          N/E         N/E
# 19          sorpresa    N/E          N/E         N/E
# 20           alegría    N/E          N/E         N/E
# 21             enojo    N/E          N/E         N/E

# %%
df_sorted = df.sort_values(
    by=['Texto', 'Fecha', 'Nombre Usuario', 'Fuente', 'Concepto asociado', 'Género', 'Grupo Étareo', 'Escolaridad'])

# Exportar el DataFrame ordenado a un archivo de Excel
df_sorted.to_excel('../csv/salida.xlsx', index=False)
